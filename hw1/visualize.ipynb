# %%
import matplotlib.pyplot as plt

# %%
x = [1000,2000,5000,8000,10000,30000,50000,80000,100000]
y = [43.02,36.18,480.89,2660.93,3412.61,3623.58,4629.73,4353.81,4501.30]
plt.plot(x,y)
plt.xlabel('num_agent_train_steps_per_iter')
plt.ylabel('Eval_AverageReturn')
# Out:
# Text(0, 0.5, 'Eval_AverageReturn')

# %%
#hopper
x = [i for i in range(0,10)]
avg = [855.9, 1418.22,3310.16,3673.42,3686.17,3741.38,3743.38,3716.51,3714.47,3722.10]
std = [10.22,228.61,430.84,5.97,6.24,2.03,3.84,1.89,4.03,2.72]
expert = [3773 for i in range(0,10)]
plt.errorbar(x,avg,std, label="Errorbar")
plt.plot(x,expert, label = 'Expert')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.title('Hopper')
# Out:
# Text(0.5, 1.0, 'Hopper')

# %%
#Ant
x = [i for i in range(0,10)]
avg = [4765.25,4626.69,4705.15,4750.06,4876.11,4710.64,4516.23,4311.40,4425.91,4512.89]
std = [119.90,403.25,105.82,156.08,68.21,64.57,835.18,1064.92,1106.63,906.49]
expert = [4713.65 for i in range(0,10)]
plt.errorbar(x,avg,std, label="Errorbar")
plt.plot(x,expert, label = 'Expert')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Value')
plt.title('Ant')
# Out:
# Text(0.5, 1.0, 'Ant')
